# %% [markdown]
# # easy-tell-finance — Colab 실행
#
# 이 노트북은 easy-tell-finance 저장소를 Colab에서 클론하고 CLI를 실행하는 방법을 안내합니다.
# `REPO_URL`을 이 저장소 주소로 바꾼 뒤 셀을 순서대로 실행합니다.

# %%
REPO_URL = "https://github.com/singularity-has-come/easy-tell-finance.git"
# !git clone "$REPO_URL" repo
# %cd repo

# %%
# !pip install -q uv
# !uv sync

# %% [markdown]
# ## 문장 변환
#
# `--text` 옵션에 원문을 넣어 CLI를 실행합니다.

# %%
# !uv run python cli.py convert --text "본 대출의 DSR이 40%를 초과하지 않는 경우..."
